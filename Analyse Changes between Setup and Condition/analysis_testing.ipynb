# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.stats as stats

# %%
df = pd.read_csv("friction_welding_data.csv")

df['report_datetime'] = df['report_date'] + ' ' + df["report_time"]
df["report_datetime"] = pd.to_datetime(df["report_datetime"])


print(df.columns)


# fig, axs = plt.subplots(5, 2, figsize=(12, 24))
# sns.boxplot(data=df, x='fcp', y='part_contact', hue='setup', ax=axs[0, 0])
# sns.pointplot(data=df, x='fcp', y='part_contact', hue='setup', errorbar='ci',ax=axs[0, 1], capsize=0.10, dodge=0.2)

# sns.boxplot(data=df, x='fcp', y='weld_up_set', hue='setup', ax=axs[1, 0])
# sns.pointplot(data=df, x='fcp', y='weld_up_set', hue='setup', errorbar='ci',ax=axs[1, 1], capsize=0.10, dodge=0.2)

# sns.boxplot(data=df, x='fcp', y='angle_deviation', hue='setup', ax=axs[2, 0])
# sns.pointplot(data=df, x='fcp', y='angle_deviation', hue='setup', errorbar='ci',ax=axs[2, 1], capsize=0.10, dodge=0.2)

# sns.boxplot(data=df, x='fcp', y='displacement_torque_rises', hue='setup', ax=axs[3, 0])
# sns.pointplot(data=df, x='fcp', y='displacement_torque_rises', hue='setup', errorbar='ci',ax=axs[3, 1], capsize=0.10, dodge=0.2)

# sns.boxplot(data=df, x='fcp', y='torque_peak', hue='setup', ax=axs[4, 0])
# sns.pointplot(data=df, x='fcp', y='torque_peak', hue='setup', errorbar='ci',ax=axs[4, 1], capsize=0.10, dodge=0.2)

# fig.savefig("friction_welding.png", dpi=300)

# test = pd.DataFrame()
# # test['stack'] = df[['part_contact', 'weld_up_set', 'angle_deviation', 'displacement_torque_rises', 'torque_peak']].stack()
# # test.reset_index(inplace=True)
# # test.drop('level_0', axis=1, inplace=True)

# test = pd.melt(df, id_vars=['setup', 'fcp', 'order', 'part_number', 'report_date', 'report_time', 'report_datetime'])
# test['index'] = range(0, len(test))

# print(test)
# sns.boxplot(test, x='fcp', y='value', hue='variable')

# # grid = sns.FacetGrid(test, col='fcp', row='setup')
# # grid.map(sns.scatterplot, 'fcp', 'value', hue='variable')
# Out:
# Index(['setup', 'fcp', 'order', 'part_number', 'report_date', 'report_time',
#        'part_contact', 'weld_up_set', 'angle_deviation',
#        'displacement_torque_rises', 'torque_peak', 'report_datetime'],
#       dtype='object')
#      setup   fcp  order                part_number  report_date report_time  \
# 0      new  91.5      1  P34235232G_72023050330AFL   2-Feb-2023    17:37:57
# 1      new  91.5      2  P34235232G_72023050330AFC   2-Feb-2023    17:38:32
# 2      new  91.5      3  P34235232G_72023050330AFJ   2-Feb-2023    17:38:44
# 3      new  91.5      4  P34235232G_72023050330AFN   2-Feb-2023    17:39:07
# 4      new  91.5      5  P34235232G_72023050330AFK   2-Feb-2023    17:39:19
# ..     ...   ...    ...                        ...          ...         ...
# 670  final  91.9     41  P34235233G_720231107403GB  15-Mar-2023    12:34:33
# 671  final  91.9     42  P34235233G_720231107403G9  15-Mar-2023    12:34:57
# ...
